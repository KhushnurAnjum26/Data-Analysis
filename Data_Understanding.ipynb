# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushnurAnjum26/Data-Analysis/blob/main/Data_Understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Understanding data-4 questions are asked-**
# 1)Asking basic questions
#
# 2)EDA with univariate
#
# 3)EDA with multivariate
#
# 4)Pandas profiler
#
# ## **1)Asking basic questions-**
#
# **Generally 7 questions are asked after fetching the csv file. These questions are given below**

# %%
import pandas as pd

# %%
df = pd.read_csv('aug_train.csv')

# %% [markdown]
# # **1)How big the data is?**

# %%
df.shape
# Out:
# (19158, 14)

# %% [markdown]
# # **2)How does the data looklike**

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
#to get any rondom row use sample function(Better option than head)

df.sample(5)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 1552         32559  city_103                   0.920   Male
# 5375         10998  city_136                   0.897   Male
# 7110          8345  city_158                   0.766   Male
# 831          22997  city_173                   0.878   Male
# 16813         2103   city_21                   0.624    NaN
#
#            relevent_experience enrolled_university education_level  \
# 1552    No relevent experience    Full time course        Graduate
# 5375   Has relevent experience       no_enrollment         Masters
# 7110    No relevent experience    Full time course        Graduate
# 831    Has relevent experience       no_enrollment         Masters
# 16813  Has relevent experience       no_enrollment        Graduate
#
#       major_discipline experience company_size    company_type last_new_job  \
# 1552              STEM          4          NaN             NaN            1
# ...

# %% [markdown]
# # **3)What is the type of cols?**

# %%
#Knowing the datatypes of the cols and check the number of values that are not-null. Also to know the memory occupy size for the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %% [markdown]
# # **4)Are there any missing value?**

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %% [markdown]
# # **5)How does the data look mathematically?**

# %%
#Will get insights for only numerical datas!That is the sole problem
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours        target
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000

# %% [markdown]
# # **6)Are there any duplicate values?**

# %%
#Check if there is any duplicate data or row

p=df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Eliminating duplicate rows

# To drop duplicate rows and keep the first occurrence
df = df.drop_duplicates()

# If you want to drop duplicates in-place without creating a new DataFrame
df.drop_duplicates(inplace=True)

# %% [markdown]
# # **7)How is the Correlation between the columns?**

# %%
#Finds pearson correlation(-1 to +1)
#- means inversely proposional
df.corr(numeric_only=True)
# Out:
#                         enrollee_id  city_development_index  training_hours  \
# enrollee_id                1.000000               -0.040455        0.000998
# city_development_index    -0.040455                1.000000        0.001920
# training_hours             0.000998                0.001920        1.000000
# target                     0.049475               -0.341665       -0.021577
#
#                           target
# enrollee_id             0.049475
# city_development_index -0.341665
# training_hours         -0.021577
# target                  1.000000

# %%
#Checks the correlation with other cols with a specific col
df.corr(numeric_only=True)['enrollee_id']
# Out:
# enrollee_id               1.000000
# city_development_index   -0.040455
# training_hours            0.000998
# target                    0.049475
# Name: enrollee_id, dtype: float64

# %%
from google.colab import drive
drive.mount('/content/drive')
